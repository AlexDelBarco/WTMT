# %%
import pandas as pd
import numpy as np

# %%
input  = [6.73, 2.03, 6.51, 1.95, 7.43, 2.80, 1.57, 2.01, 4.93, 3.79]

# %%
input
# Out:
# [6.73, 2.03, 6.51, 1.95, 7.43, 2.8, 1.57, 2.01, 4.93, 3.79]

# %%
def dev(num, n, num_dig, last):
    parts = 2**n
    length = num_dig/(parts)
    print(parts)
    if last == 0:
        lb = half*1
        if num > lb:
            output = 1
        if num <= lb:
            output = 0
    if last == 1:
        lb = half*3
        if num > lb:
            output = 1
        if num <= lb:
            output = 0
        
    return output

# %%
results = {}
for i in input:
    num = i
    print(num)
    num_dig = 8
    results[i] = []
    for y in range(1,num_dig):
        
        if y == 1:
            last = 0
        else:
            last = results[i][-1]
        print(last)
        n = y
        print(n)
        
        op = dev(num, n, num_dig, last)
        results[i].append(op)
# Out:
# 6.73
# 0
# 1
# 4.0
# 1
# 2
# 2.0
# 1
# 3
# 1.0
# 1
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 2.03
# 0
# 1
# 4.0
# 0
# 2
# 2.0
# 1
# 3
# 1.0
# 0
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 6.51
# 0
# 1
# 4.0
# 1
# 2
# 2.0
# 1
# 3
# 1.0
# 1
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 1.95
# 0
# 1
# 4.0
# 0
# 2
# 2.0
# 0
# 3
# 1.0
# 1
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 7.43
# 0
# 1
# 4.0
# 1
# 2
# 2.0
# 1
# 3
# 1.0
# 1
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 2.8
# 0
# 1
# 4.0
# 0
# 2
# 2.0
# 1
# 3
# 1.0
# 0
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 1.57
# 0
# 1
# 4.0
# 0
# 2
# 2.0
# 0
# 3
# 1.0
# 1
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 2.01
# 0
# 1
# 4.0
# 0
# 2
# 2.0
# 1
# 3
# 1.0
# 0
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# 4.93
# 0
# 1
# 4.0
# 1
# 2
# 2.0
# 0
# 3
# 1.0
# 1
# 4
# 0.5
# 1
# 5
# 0.25
# 1
# 6
# 0.125
# 1
# 7
# 0.0625
# ...

# %%
results
# Out:
# {6.73: [1, 1, 1, 1, 1, 1, 1],
#  2.03: [0, 1, 0, 1, 1, 1, 1],
#  6.51: [1, 1, 1, 1, 1, 1, 1],
#  1.95: [0, 0, 1, 1, 1, 1, 1],
#  7.43: [1, 1, 1, 1, 1, 1, 1],
#  2.8: [0, 1, 0, 1, 1, 1, 1],
#  1.57: [0, 0, 1, 1, 1, 1, 1],
#  2.01: [0, 1, 0, 1, 1, 1, 1],
#  4.93: [1, 0, 1, 1, 1, 1, 1],
#  3.79: [0, 1, 1, 1, 1, 1, 1]}
